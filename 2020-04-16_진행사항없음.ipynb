# %% [markdown]
# # 서론
#
# ## 주제
# ## 목표
# ## 개념
#
# ---
#
# # 본론
#
# ## 설계

# %% [markdown]
# ---
#
# # 결론
#
# ## 해석
# ## 고찰
# ## 계획
#
# ---
#
# # 부록
#
# ---
#
# # 세미나
#
# ## 1. 심태섭
#
# ### 분류: 본인의 연구주제 선정에 대한 피드백
# ### 주제: indoor localization
#
# 주제: 자율주행을 위한 맵 만들기?
# * 위치, 센싱, 지도, 경로... ->
#
# 반: 무슨 지도라는건지가 명확하지 않은데? / 어디에 사용될 수 있는지 / 공학적으로 생각: 카페에 맵이 있으면 뭐함.
#
# 오차율을 줄일 수 있는 방식: 어떻게? --> 로봇에 대한 위치? 바퀴 회전 수에 따른 데이터 생성
#
#
# 벽에 부딫히며 데이터 생성?
#
# 심: Localization 쪽은 안하고 다른쪽으로 딥러닝 쪽으로? 계획을 세우는게 맞는지 고민
#
# 반: 그림이 그려지지 않음. 어떤 센서로 센싱 -> 센싱 데이터로 맵 모델링 --> ... 을 해야 할 것 같은데, 그러기 위한 기초(연구)가 없다.
#
# 반: 본인은 구상한 것을 바탕으로 구현이 가능할 것이라 생각?
# 심: 많은 노력이 필요할 것 같음...
# ...
# 반: 센터에서 하고 있는 과제는 본인(심)이 주도적?
# 심: 의견제시 단계, 사실 주도적으로 다 개발하지는 않았음.
# 반: 결과를 (기반으로 다른거에) 활용하기도 애매하겠네요.
# 심: 그 정도면 노력해서 해볼수도 있을지도.
# 반: 본인이 주도적으로 했으면 활용이 가능했을텐데, 결과도 많이 없네? 그것도.. 2m 오차가 생기는 결과
# 심: 그 부분은 사실 고민을 좀 하고있음.
# 반: 고민해봅시다.. 이거는 할게 하나하나가 많을 것 같다. 지금도 구체적이지는 않고.
#
#
# ## 2. 오재호
# ### 분류: Paper Scanning
# ### 주제: Densely Connected Convolutional nearal networks
